# %% [markdown]
# # Movie Genre Classification Exploration
#
# This notebook is a quick exploratory entry point for the Kaggle IMDb genre dataset.

# %%
import os
import kagglehub
import pandas as pd

path = kagglehub.dataset_download('hijest/genre-classification-dataset-imdb')
print('Download path:', path)
for root, _, files in os.walk(path):
    for file in files:
        print(os.path.join(root, file))

# %%
from src.data_loader import load_dataset
_, df, _ = load_dataset()
df.head()
